# %%
#mengaitkan gdrive dengan google colab
from google.colab import drive
import os
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# #setting direktori dataset
# base_dir = '/content/drive/MyDrive/DATASET BATIK MANUAL'
# !ls "/content/drive/MyDrive/DATASET BATIK MANUAL"

# %%
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout
import os, sys
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import sklearn.metrics as metrics
import seaborn as sn
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from numpy import expand_dims
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import models
import pandas as pd
from imutils import paths
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras

# %%
#memanggil seluruh citra dan menampungnya ke dalam array yang sudah disediakan, serta merize sesuai kebutuhan
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_std_normalization= True,
                                   horizontal_flip=True,
                                   vertical_flip= True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory('/content/drive/MyDrive/SHEAR AUG BATIK/DATA TRAIN',
                                                    target_size=(300, 300),
                                                    batch_size= 64,
                                                    shuffle= False,
                                                    class_mode= 'categorical')

validation_generator = test_datagen.flow_from_directory('/content/drive/MyDrive/SHEAR AUG BATIK/DATA VAL',
                                                        batch_size= 64,
                                                        target_size=(300, 300),
                                                        shuffle= True,
                                                        class_mode= 'categorical')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1460: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn(
# Found 2400 images belonging to 6 classes.
# Found 600 images belonging to 6 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)  #Image normalization.

test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/SHEAR AUG BATIK/DATA TEST',
                                            target_size = (300, 300),
                                            batch_size = 64,
                                            shuffle= False,
                                            class_mode = 'categorical')
# Out:
# Found 300 images belonging to 6 classes.

# %%
class_indices = train_generator.class_indices
print (class_indices)
# Out:
# {'CEPLOK': 0, 'KAWUNG': 1, 'MEGAMENDUNG': 2, 'NITIK': 3, 'PARANG': 4, 'TAMBAL': 5}

# %%
labels_train= train_generator.classes
print(labels_train)
# Out:
# [0 0 0 ... 5 5 5]

# %%
#Menampilkan data prepocessing
image_path = '/content/drive/MyDrive/SHEAR AUG BATIK/DATA TRAIN/MEGAMENDUNG/NonGMB_Aug__0_1124.jpg'

img = keras.preprocessing.image.load_img(image_path, target_size= (300, 300))
img_tensor = keras.preprocessing.image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

#Uses ImageDataGenerator to flip the images
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip= True)
#Creates our batch of one image
pic = datagen.flow(img_tensor, batch_size =64)
plt.figure(figsize=(20,10))

#Plots our figures
for i in range(1,4):
  plt.subplot(1, 3, i)
  batch = pic.next()
  image_ = batch[0].astype('uint8')
  plt.imshow(image_)
plt.show()

# %%
#Uses ImageDataGenerator to flip the images
datagen = ImageDataGenerator(brightness_range=[0.1, 2.5])
#Creates our batch of one image
pic = datagen.flow(img_tensor, batch_size =64)
plt.figure(figsize=(20,10))

#Plots our figures
for i in range(1, 4):
  plt.subplot(1, 3, i)
  batch = pic.next()
  image_ = batch[0].astype('uint8')
  plt.imshow(image_)
plt.show()

# %%
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Flatten, Dense, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2
import tensorflow as tf


model = tf.keras.Sequential([
    ResNet152V2(
        include_top=False,
        weights='imagenet',
        input_shape=(300, 300, 3)),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    # tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax', name='classification')
])
model.layers[0].trainable = False
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step

# %%
model.summary()
plt.savefig("ModelSummary.jpg")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 10, 10, 2048)      58331648
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  classification (Dense)      (None, 6)                 774
#
# =================================================================
# Total params: 58,594,694
# Trainable params: 263,046
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
# Compile the Neural network
opt = tf.keras.optimizers.Adagrad(learning_rate=0.0001)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

filepath = 'model_Batik.h5'
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience= 10)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint, es]

# %%
#save the model history in a list after fitting so taht we can plot later
model_history = []
history = model.fit(
        train_generator,
        validation_data=validation_generator,
        batch_size=64,
        epochs=100,
        callbacks=[checkpoint, es])

# Evaluasi model pada data pelatihan
train_score = model.evaluate(train_generator)
print('Train Score:', train_score)

val_score = model.evaluate(validation_generator)
print('Val Score:', val_score)

test_score = model.evaluate(test_set)
print('Test Score:', test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1861: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1871: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0378 - accuracy: 0.1358
# Epoch 1: val_loss improved from inf to 1.95023, saving model to model_Batik.h5
# 38/38 [==============================] - 498s 13s/step - loss: 2.0378 - accuracy: 0.1358 - val_loss: 1.9502 - val_accuracy: 0.1233
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9569 - accuracy: 0.1700
# Epoch 2: val_loss improved from 1.95023 to 1.89148, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.9569 - accuracy: 0.1700 - val_loss: 1.8915 - val_accuracy: 0.1483
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8970 - accuracy: 0.2042
# Epoch 3: val_loss improved from 1.89148 to 1.84488, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.8970 - accuracy: 0.2042 - val_loss: 1.8449 - val_accuracy: 0.1683
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8407 - accuracy: 0.2429
# Epoch 4: val_loss improved from 1.84488 to 1.80565, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.8407 - accuracy: 0.2429 - val_loss: 1.8057 - val_accuracy: 0.1867
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8054 - accuracy: 0.2642
# Epoch 5: val_loss improved from 1.80565 to 1.77117, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.8054 - accuracy: 0.2642 - val_loss: 1.7712 - val_accuracy: 0.2017
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7658 - accuracy: 0.2917
# Epoch 6: val_loss improved from 1.77117 to 1.74020, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.7658 - accuracy: 0.2917 - val_loss: 1.7402 - val_accuracy: 0.2200
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7289 - accuracy: 0.3133
# Epoch 7: val_loss improved from 1.74020 to 1.71192, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.7289 - accuracy: 0.3133 - val_loss: 1.7119 - val_accuracy: 0.2483
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7024 - accuracy: 0.3325
# Epoch 8: val_loss improved from 1.71192 to 1.68608, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.7024 - accuracy: 0.3325 - val_loss: 1.6861 - val_accuracy: 0.2700
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6686 - accuracy: 0.3483
# Epoch 9: val_loss improved from 1.68608 to 1.66201, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.6686 - accuracy: 0.3483 - val_loss: 1.6620 - val_accuracy: 0.3100
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6430 - accuracy: 0.3646
# Epoch 10: val_loss improved from 1.66201 to 1.63960, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.6430 - accuracy: 0.3646 - val_loss: 1.6396 - val_accuracy: 0.3333
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6313 - accuracy: 0.3783
# Epoch 11: val_loss improved from 1.63960 to 1.61848, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.6313 - accuracy: 0.3783 - val_loss: 1.6185 - val_accuracy: 0.3483
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5998 - accuracy: 0.4062
# Epoch 12: val_loss improved from 1.61848 to 1.59861, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5998 - accuracy: 0.4062 - val_loss: 1.5986 - val_accuracy: 0.3633
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5768 - accuracy: 0.4054
# Epoch 13: val_loss improved from 1.59861 to 1.57993, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5768 - accuracy: 0.4054 - val_loss: 1.5799 - val_accuracy: 0.3733
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5550 - accuracy: 0.4271
# Epoch 14: val_loss improved from 1.57993 to 1.56226, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5550 - accuracy: 0.4271 - val_loss: 1.5623 - val_accuracy: 0.3900
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5365 - accuracy: 0.4442
# Epoch 15: val_loss improved from 1.56226 to 1.54548, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5365 - accuracy: 0.4442 - val_loss: 1.5455 - val_accuracy: 0.4033
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5196 - accuracy: 0.4450
# Epoch 16: val_loss improved from 1.54548 to 1.52932, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5196 - accuracy: 0.4450 - val_loss: 1.5293 - val_accuracy: 0.4217
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5044 - accuracy: 0.4588
# Epoch 17: val_loss improved from 1.52932 to 1.51391, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.5044 - accuracy: 0.4588 - val_loss: 1.5139 - val_accuracy: 0.4317
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4825 - accuracy: 0.4654
# Epoch 18: val_loss improved from 1.51391 to 1.49898, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.4825 - accuracy: 0.4654 - val_loss: 1.4990 - val_accuracy: 0.4450
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4675 - accuracy: 0.4863
# Epoch 19: val_loss improved from 1.49898 to 1.48484, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.4675 - accuracy: 0.4863 - val_loss: 1.4848 - val_accuracy: 0.4583
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4528 - accuracy: 0.4900
# Epoch 20: val_loss improved from 1.48484 to 1.47117, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.4528 - accuracy: 0.4900 - val_loss: 1.4712 - val_accuracy: 0.4683
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4353 - accuracy: 0.5025
# Epoch 21: val_loss improved from 1.47117 to 1.45806, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.4353 - accuracy: 0.5025 - val_loss: 1.4581 - val_accuracy: 0.4783
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4216 - accuracy: 0.5029
# Epoch 22: val_loss improved from 1.45806 to 1.44540, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.4216 - accuracy: 0.5029 - val_loss: 1.4454 - val_accuracy: 0.4833
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4053 - accuracy: 0.5158
# Epoch 23: val_loss improved from 1.44540 to 1.43318, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.4053 - accuracy: 0.5158 - val_loss: 1.4332 - val_accuracy: 0.4967
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3926 - accuracy: 0.5229
# Epoch 24: val_loss improved from 1.43318 to 1.42147, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.3926 - accuracy: 0.5229 - val_loss: 1.4215 - val_accuracy: 0.5033
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3776 - accuracy: 0.5308
# Epoch 25: val_loss improved from 1.42147 to 1.41018, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.3776 - accuracy: 0.5308 - val_loss: 1.4102 - val_accuracy: 0.5100
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3646 - accuracy: 0.5433
# Epoch 26: val_loss improved from 1.41018 to 1.39916, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.3646 - accuracy: 0.5433 - val_loss: 1.3992 - val_accuracy: 0.5117
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3519 - accuracy: 0.5458
# Epoch 27: val_loss improved from 1.39916 to 1.38859, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.3519 - accuracy: 0.5458 - val_loss: 1.3886 - val_accuracy: 0.5150
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3440 - accuracy: 0.5475
# Epoch 28: val_loss improved from 1.38859 to 1.37833, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.3440 - accuracy: 0.5475 - val_loss: 1.3783 - val_accuracy: 0.5200
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3297 - accuracy: 0.5562
# Epoch 29: val_loss improved from 1.37833 to 1.36830, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.3297 - accuracy: 0.5562 - val_loss: 1.3683 - val_accuracy: 0.5233
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3179 - accuracy: 0.5650
# Epoch 30: val_loss improved from 1.36830 to 1.35858, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.3179 - accuracy: 0.5650 - val_loss: 1.3586 - val_accuracy: 0.5283
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3027 - accuracy: 0.5767
# Epoch 31: val_loss improved from 1.35858 to 1.34923, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.3027 - accuracy: 0.5767 - val_loss: 1.3492 - val_accuracy: 0.5317
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2959 - accuracy: 0.5775
# Epoch 32: val_loss improved from 1.34923 to 1.34010, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.2959 - accuracy: 0.5775 - val_loss: 1.3401 - val_accuracy: 0.5367
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2829 - accuracy: 0.5892
# Epoch 33: val_loss improved from 1.34010 to 1.33124, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.2829 - accuracy: 0.5892 - val_loss: 1.3312 - val_accuracy: 0.5400
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2797 - accuracy: 0.5825
# Epoch 34: val_loss improved from 1.33124 to 1.32260, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2797 - accuracy: 0.5825 - val_loss: 1.3226 - val_accuracy: 0.5467
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2622 - accuracy: 0.5996
# Epoch 35: val_loss improved from 1.32260 to 1.31416, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2622 - accuracy: 0.5996 - val_loss: 1.3142 - val_accuracy: 0.5533
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2560 - accuracy: 0.6033
# Epoch 36: val_loss improved from 1.31416 to 1.30588, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2560 - accuracy: 0.6033 - val_loss: 1.3059 - val_accuracy: 0.5567
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2475 - accuracy: 0.6108
# Epoch 37: val_loss improved from 1.30588 to 1.29785, saving model to model_Batik.h5
# 38/38 [==============================] - 45s 1s/step - loss: 1.2475 - accuracy: 0.6108 - val_loss: 1.2979 - val_accuracy: 0.5617
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2382 - accuracy: 0.6129
# Epoch 38: val_loss improved from 1.29785 to 1.29002, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2382 - accuracy: 0.6129 - val_loss: 1.2900 - val_accuracy: 0.5650
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2294 - accuracy: 0.6100
# Epoch 39: val_loss improved from 1.29002 to 1.28239, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2294 - accuracy: 0.6100 - val_loss: 1.2824 - val_accuracy: 0.5717
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2209 - accuracy: 0.6288
# Epoch 40: val_loss improved from 1.28239 to 1.27491, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.2209 - accuracy: 0.6288 - val_loss: 1.2749 - val_accuracy: 0.5733
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2051 - accuracy: 0.6346
# Epoch 41: val_loss improved from 1.27491 to 1.26759, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.2051 - accuracy: 0.6346 - val_loss: 1.2676 - val_accuracy: 0.5800
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2020 - accuracy: 0.6358
# Epoch 42: val_loss improved from 1.26759 to 1.26050, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.2020 - accuracy: 0.6358 - val_loss: 1.2605 - val_accuracy: 0.5867
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1917 - accuracy: 0.6421
# Epoch 43: val_loss improved from 1.26050 to 1.25357, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1917 - accuracy: 0.6421 - val_loss: 1.2536 - val_accuracy: 0.5917
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1813 - accuracy: 0.6525
# Epoch 44: val_loss improved from 1.25357 to 1.24679, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1813 - accuracy: 0.6525 - val_loss: 1.2468 - val_accuracy: 0.5933
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1782 - accuracy: 0.6471
# Epoch 45: val_loss improved from 1.24679 to 1.24010, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.1782 - accuracy: 0.6471 - val_loss: 1.2401 - val_accuracy: 0.5933
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1725 - accuracy: 0.6579
# Epoch 46: val_loss improved from 1.24010 to 1.23355, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.1725 - accuracy: 0.6579 - val_loss: 1.2335 - val_accuracy: 0.5950
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1593 - accuracy: 0.6629
# Epoch 47: val_loss improved from 1.23355 to 1.22713, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1593 - accuracy: 0.6629 - val_loss: 1.2271 - val_accuracy: 0.6000
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1543 - accuracy: 0.6700
# Epoch 48: val_loss improved from 1.22713 to 1.22077, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1543 - accuracy: 0.6700 - val_loss: 1.2208 - val_accuracy: 0.6017
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1522 - accuracy: 0.6708
# Epoch 49: val_loss improved from 1.22077 to 1.21462, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1522 - accuracy: 0.6708 - val_loss: 1.2146 - val_accuracy: 0.6050
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1356 - accuracy: 0.6721
# Epoch 50: val_loss improved from 1.21462 to 1.20861, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1356 - accuracy: 0.6721 - val_loss: 1.2086 - val_accuracy: 0.6067
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1299 - accuracy: 0.6804
# Epoch 51: val_loss improved from 1.20861 to 1.20269, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.1299 - accuracy: 0.6804 - val_loss: 1.2027 - val_accuracy: 0.6067
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1261 - accuracy: 0.6817
# Epoch 52: val_loss improved from 1.20269 to 1.19695, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1261 - accuracy: 0.6817 - val_loss: 1.1969 - val_accuracy: 0.6083
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1207 - accuracy: 0.6888
# Epoch 53: val_loss improved from 1.19695 to 1.19127, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.1207 - accuracy: 0.6888 - val_loss: 1.1913 - val_accuracy: 0.6100
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1119 - accuracy: 0.7046
# Epoch 54: val_loss improved from 1.19127 to 1.18560, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1119 - accuracy: 0.7046 - val_loss: 1.1856 - val_accuracy: 0.6100
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1024 - accuracy: 0.6996
# Epoch 55: val_loss improved from 1.18560 to 1.18010, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.1024 - accuracy: 0.6996 - val_loss: 1.1801 - val_accuracy: 0.6117
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0982 - accuracy: 0.7025
# Epoch 56: val_loss improved from 1.18010 to 1.17469, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0982 - accuracy: 0.7025 - val_loss: 1.1747 - val_accuracy: 0.6167
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.7113
# Epoch 57: val_loss improved from 1.17469 to 1.16940, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0880 - accuracy: 0.7113 - val_loss: 1.1694 - val_accuracy: 0.6167
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0861 - accuracy: 0.7142
# Epoch 58: val_loss improved from 1.16940 to 1.16418, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0861 - accuracy: 0.7142 - val_loss: 1.1642 - val_accuracy: 0.6167
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0748 - accuracy: 0.7146
# Epoch 59: val_loss improved from 1.16418 to 1.15905, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0748 - accuracy: 0.7146 - val_loss: 1.1591 - val_accuracy: 0.6183
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0717 - accuracy: 0.7138
# Epoch 60: val_loss improved from 1.15905 to 1.15397, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0717 - accuracy: 0.7138 - val_loss: 1.1540 - val_accuracy: 0.6200
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0645 - accuracy: 0.7179
# Epoch 61: val_loss improved from 1.15397 to 1.14901, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0645 - accuracy: 0.7179 - val_loss: 1.1490 - val_accuracy: 0.6200
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0629 - accuracy: 0.7108
# Epoch 62: val_loss improved from 1.14901 to 1.14413, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0629 - accuracy: 0.7108 - val_loss: 1.1441 - val_accuracy: 0.6217
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0563 - accuracy: 0.7200
# Epoch 63: val_loss improved from 1.14413 to 1.13927, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.0563 - accuracy: 0.7200 - val_loss: 1.1393 - val_accuracy: 0.6250
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0451 - accuracy: 0.7283
# Epoch 64: val_loss improved from 1.13927 to 1.13456, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0451 - accuracy: 0.7283 - val_loss: 1.1346 - val_accuracy: 0.6267
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0444 - accuracy: 0.7304
# Epoch 65: val_loss improved from 1.13456 to 1.12988, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0444 - accuracy: 0.7304 - val_loss: 1.1299 - val_accuracy: 0.6283
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0309 - accuracy: 0.7367
# Epoch 66: val_loss improved from 1.12988 to 1.12526, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.0309 - accuracy: 0.7367 - val_loss: 1.1253 - val_accuracy: 0.6300
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.7417
# Epoch 67: val_loss improved from 1.12526 to 1.12076, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.0298 - accuracy: 0.7417 - val_loss: 1.1208 - val_accuracy: 0.6333
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0289 - accuracy: 0.7362
# Epoch 68: val_loss improved from 1.12076 to 1.11628, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 1.0289 - accuracy: 0.7362 - val_loss: 1.1163 - val_accuracy: 0.6350
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0149 - accuracy: 0.7408
# Epoch 69: val_loss improved from 1.11628 to 1.11192, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 1.0149 - accuracy: 0.7408 - val_loss: 1.1119 - val_accuracy: 0.6350
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0157 - accuracy: 0.7500
# Epoch 70: val_loss improved from 1.11192 to 1.10764, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0157 - accuracy: 0.7500 - val_loss: 1.1076 - val_accuracy: 0.6350
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0108 - accuracy: 0.7475
# Epoch 71: val_loss improved from 1.10764 to 1.10344, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0108 - accuracy: 0.7475 - val_loss: 1.1034 - val_accuracy: 0.6400
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0009 - accuracy: 0.7542
# Epoch 72: val_loss improved from 1.10344 to 1.09925, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 1.0009 - accuracy: 0.7542 - val_loss: 1.0993 - val_accuracy: 0.6433
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9996 - accuracy: 0.7487
# Epoch 73: val_loss improved from 1.09925 to 1.09504, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9996 - accuracy: 0.7487 - val_loss: 1.0950 - val_accuracy: 0.6467
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9848 - accuracy: 0.7617
# Epoch 74: val_loss improved from 1.09504 to 1.09090, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9848 - accuracy: 0.7617 - val_loss: 1.0909 - val_accuracy: 0.6483
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9812 - accuracy: 0.7538
# Epoch 75: val_loss improved from 1.09090 to 1.08688, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9812 - accuracy: 0.7538 - val_loss: 1.0869 - val_accuracy: 0.6500
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9813 - accuracy: 0.7567
# Epoch 76: val_loss improved from 1.08688 to 1.08294, saving model to model_Batik.h5
# 38/38 [==============================] - 53s 1s/step - loss: 0.9813 - accuracy: 0.7567 - val_loss: 1.0829 - val_accuracy: 0.6517
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9754 - accuracy: 0.7675
# Epoch 77: val_loss improved from 1.08294 to 1.07905, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 0.9754 - accuracy: 0.7675 - val_loss: 1.0790 - val_accuracy: 0.6533
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9741 - accuracy: 0.7608
# Epoch 78: val_loss improved from 1.07905 to 1.07518, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9741 - accuracy: 0.7608 - val_loss: 1.0752 - val_accuracy: 0.6550
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9638 - accuracy: 0.7679
# Epoch 79: val_loss improved from 1.07518 to 1.07136, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9638 - accuracy: 0.7679 - val_loss: 1.0714 - val_accuracy: 0.6583
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.7696
# Epoch 80: val_loss improved from 1.07136 to 1.06759, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 0.9635 - accuracy: 0.7696 - val_loss: 1.0676 - val_accuracy: 0.6617
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.7704
# Epoch 81: val_loss improved from 1.06759 to 1.06388, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9597 - accuracy: 0.7704 - val_loss: 1.0639 - val_accuracy: 0.6617
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9495 - accuracy: 0.7729
# Epoch 82: val_loss improved from 1.06388 to 1.06019, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.9495 - accuracy: 0.7729 - val_loss: 1.0602 - val_accuracy: 0.6617
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9494 - accuracy: 0.7708
# Epoch 83: val_loss improved from 1.06019 to 1.05656, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9494 - accuracy: 0.7708 - val_loss: 1.0566 - val_accuracy: 0.6633
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9419 - accuracy: 0.7742
# Epoch 84: val_loss improved from 1.05656 to 1.05296, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9419 - accuracy: 0.7742 - val_loss: 1.0530 - val_accuracy: 0.6633
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9426 - accuracy: 0.7758
# Epoch 85: val_loss improved from 1.05296 to 1.04940, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9426 - accuracy: 0.7758 - val_loss: 1.0494 - val_accuracy: 0.6667
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9369 - accuracy: 0.7767
# Epoch 86: val_loss improved from 1.04940 to 1.04588, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9369 - accuracy: 0.7767 - val_loss: 1.0459 - val_accuracy: 0.6733
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9342 - accuracy: 0.7792
# Epoch 87: val_loss improved from 1.04588 to 1.04237, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9342 - accuracy: 0.7792 - val_loss: 1.0424 - val_accuracy: 0.6750
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9280 - accuracy: 0.7825
# Epoch 88: val_loss improved from 1.04237 to 1.03892, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.9280 - accuracy: 0.7825 - val_loss: 1.0389 - val_accuracy: 0.6750
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9234 - accuracy: 0.7837
# Epoch 89: val_loss improved from 1.03892 to 1.03556, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.9234 - accuracy: 0.7837 - val_loss: 1.0356 - val_accuracy: 0.6767
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9232 - accuracy: 0.7771
# Epoch 90: val_loss improved from 1.03556 to 1.03222, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9232 - accuracy: 0.7771 - val_loss: 1.0322 - val_accuracy: 0.6767
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9124 - accuracy: 0.7854
# Epoch 91: val_loss improved from 1.03222 to 1.02890, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9124 - accuracy: 0.7854 - val_loss: 1.0289 - val_accuracy: 0.6817
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9118 - accuracy: 0.7829
# Epoch 92: val_loss improved from 1.02890 to 1.02565, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.9118 - accuracy: 0.7829 - val_loss: 1.0257 - val_accuracy: 0.6850
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9060 - accuracy: 0.7929
# Epoch 93: val_loss improved from 1.02565 to 1.02242, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9060 - accuracy: 0.7929 - val_loss: 1.0224 - val_accuracy: 0.6850
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9031 - accuracy: 0.7862
# Epoch 94: val_loss improved from 1.02242 to 1.01925, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.9031 - accuracy: 0.7862 - val_loss: 1.0192 - val_accuracy: 0.6850
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8977 - accuracy: 0.7937
# Epoch 95: val_loss improved from 1.01925 to 1.01610, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 0.8977 - accuracy: 0.7937 - val_loss: 1.0161 - val_accuracy: 0.6883
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8890 - accuracy: 0.7962
# Epoch 96: val_loss improved from 1.01610 to 1.01299, saving model to model_Batik.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.8890 - accuracy: 0.7962 - val_loss: 1.0130 - val_accuracy: 0.6883
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8937 - accuracy: 0.7992
# Epoch 97: val_loss improved from 1.01299 to 1.00987, saving model to model_Batik.h5
# 38/38 [==============================] - 43s 1s/step - loss: 0.8937 - accuracy: 0.7992 - val_loss: 1.0099 - val_accuracy: 0.6900
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8884 - accuracy: 0.7979
# Epoch 98: val_loss improved from 1.00987 to 1.00681, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 0.8884 - accuracy: 0.7979 - val_loss: 1.0068 - val_accuracy: 0.6900
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8848 - accuracy: 0.7942
# Epoch 99: val_loss improved from 1.00681 to 1.00382, saving model to model_Batik.h5
# 38/38 [==============================] - 44s 1s/step - loss: 0.8848 - accuracy: 0.7942 - val_loss: 1.0038 - val_accuracy: 0.6883
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.7937
# Epoch 100: val_loss improved from 1.00382 to 1.00085, saving model to model_Batik.h5
# 38/38 [==============================] - 46s 1s/step - loss: 0.8824 - accuracy: 0.7937 - val_loss: 1.0009 - val_accuracy: 0.6900
# 38/38 [==============================] - 32s 832ms/step - loss: 0.8778 - accuracy: 0.8004
# Train Score: [0.8777845501899719, 0.8004166483879089]
# 10/10 [==============================] - 10s 955ms/step - loss: 1.0009 - accuracy: 0.6900
# Val Score: [1.0008529424667358, 0.6899999976158142]
# 5/5 [==============================] - 53s 13s/step - loss: 1.0852 - accuracy: 0.6967
# Test Score: [1.0852141380310059, 0.6966666579246521]

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Prediksi label menggunakan model
y_pred = model.predict_generator(test_set, steps=len(test_set))

# Ambil label yang sebenarnya
y_true = test_set.classes
# Out:
# <ipython-input-16-bb0447526716>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_set, steps=len(test_set))

# %%
# Hitung confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
print(conf_matrix)

# # plot confusion matrix
# plt.imshow(conf_matrix, cmap=plt.cm.Blues)
# plt.title('Confusion Matrix')

df_cm = pd.DataFrame(conf_matrix, index= test_set.class_indices, columns= test_set.class_indices)

# plot confusion matrix using seaborn heatmap
sns.heatmap(df_cm, annot=True, fmt= 'd')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()
# Out:
# [[ 6  8  0 10  2 24]
#  [ 0 47  0  0  0  3]
#  [ 0  0 50  0  0  0]
#  [ 4 10  0 26  4  6]
#  [ 2  6 12  0 30  0]
#  [ 0  0  0  0  0 50]]

# %%
# Step 1: Predict on test data
y_pred_prob = model.predict_generator(test_set)

# Step 2: Get class with highest probability
y_pred = np.argmax(y_pred_prob, axis=1)

# Step 3: Calculate accuracy score
from sklearn.metrics import accuracy_score
y_true = test_set.classes
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# <ipython-input-18-4c125e6a6fc1>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_prob = model.predict_generator(test_set)
# Accuracy: 0.6966666666666667

# %%
# membuat classification report
from sklearn.metrics import classification_report
report = classification_report(y_true, y_pred, target_names=test_set.class_indices)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       CEPLOK       0.50      0.12      0.19        50
#       KAWUNG       0.66      0.94      0.78        50
#  MEGAMENDUNG       0.81      1.00      0.89        50
#        NITIK       0.72      0.52      0.60        50
#       PARANG       0.83      0.60      0.70        50
#       TAMBAL       0.60      1.00      0.75        50
#
#     accuracy                           0.70       300
#    macro avg       0.69      0.70      0.65       300
# weighted avg       0.69      0.70      0.65       300

# %%
from PIL import Image
import numpy as np
from keras.models import load_model


classes = ['Ceplok', 'Kawung', 'Megamendung', 'Nitik', 'Parang', 'Tambal']
loaded_model = load_model ('model_Batik.h5')

image_testing = Image.open('/content/drive/MyDrive/SHEAR AUG BATIK/DATA TEST/CEPLOK/NonGMB_Aug__0_152.jpg')
image_testing = np.array(image_testing.resize((300, 300)))/255.0
plt.imshow(image_testing)
image_testing.shape

image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)

output = model.predict(image_testing)
best_index = np.argmax(output)
class_name = classes[best_index]

print(output)
print(best_index)

print(classes[best_index])
# Out:
# (1, 300, 300, 3)
# 1/1 [==============================] - 3s 3s/step
# [[0.22322363 0.1818465  0.12325442 0.15715188 0.0990238  0.21549977]]
# 0
# Ceplok
