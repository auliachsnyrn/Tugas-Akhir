# %%
#mengaitkan gdrive dengan google colab
from google.colab import drive
import os
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# #setting direktori dataset
# base_dir = '/content/drive/MyDrive/DATASET BATIK MANUAL'
# !ls "/content/drive/MyDrive/DATASET BATIK MANUAL"

# %%
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout
import os, sys
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import sklearn.metrics as metrics
import seaborn as sn
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from numpy import expand_dims
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import models
import pandas as pd
from imutils import paths
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras

# %%
#memanggil seluruh citra dan menampungnya ke dalam array yang sudah disediakan, serta merize sesuai kebutuhan
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_std_normalization= True,
                                   horizontal_flip=True,
                                   vertical_flip= True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory('/content/drive/MyDrive/ROTATION AUG BATIK/DATA TRAIN',
                                                    target_size=(300, 300),
                                                    batch_size= 64,
                                                    shuffle= False,
                                                    class_mode= 'categorical')

validation_generator = test_datagen.flow_from_directory('/content/drive/MyDrive/ROTATION AUG BATIK/DATA VAL',
                                                        batch_size= 64,
                                                        target_size=(300, 300),
                                                        shuffle= True,
                                                        class_mode= 'categorical')
# Out:
# Found 2400 images belonging to 6 classes.
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1460: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn(
# Found 600 images belonging to 6 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)  #Image normalization.

test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/ROTATION AUG BATIK/DATA TEST',
                                            target_size = (300, 300),
                                            batch_size = 64,
                                            shuffle= False,
                                            class_mode = 'categorical')
# Out:
# Found 300 images belonging to 6 classes.

# %%
class_indices = train_generator.class_indices
print (class_indices)
# Out:
# {'CEPLOK': 0, 'KAWUNG': 1, 'MEGAMENDUNG': 2, 'NITIK': 3, 'PARANG': 4, 'TAMBAL': 5}

# %%
labels_train= train_generator.classes
print(labels_train)
# Out:
# [0 0 0 ... 5 5 5]

# %%
#Menampilkan data prepocessing
image_path = '/content/drive/MyDrive/ROTATION AUG BATIK/DATA TRAIN/MEGAMENDUNG/NonGMB_Aug__0_1308.jpg'

img = keras.preprocessing.image.load_img(image_path, target_size= (300, 300))
img_tensor = keras.preprocessing.image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

#Uses ImageDataGenerator to flip the images
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip= True)
#Creates our batch of one image
pic = datagen.flow(img_tensor, batch_size =64)
plt.figure(figsize=(20,10))

#Plots our figures
for i in range(1,4):
  plt.subplot(1, 3, i)
  batch = pic.next()
  image_ = batch[0].astype('uint8')
  plt.imshow(image_)
plt.show()

# %%
#Uses ImageDataGenerator to flip the images
datagen = ImageDataGenerator(brightness_range=[0.1, 2.5])
#Creates our batch of one image
pic = datagen.flow(img_tensor, batch_size =64)
plt.figure(figsize=(20,10))

#Plots our figures
for i in range(1, 4):
  plt.subplot(1, 3, i)
  batch = pic.next()
  image_ = batch[0].astype('uint8')
  plt.imshow(image_)
plt.show()

# %%
from tensorflow.keras.applications import ResNet50V2, ResNet101V2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Flatten, Dense, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2
import tensorflow as tf


model = tf.keras.Sequential([
    ResNet101V2(
        include_top= False,
        weights= 'imagenet',
        input_shape=(300, 300, 3)),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    # tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax', name='classification')
])
model.layers[0].trainable = False
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
plt.savefig("ModelSummary.jpg")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101v2 (Functional)    (None, 10, 10, 2048)      42626560
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  classification (Dense)      (None, 6)                 774
#
# =================================================================
# Total params: 42,889,606
# Trainable params: 263,046
# Non-trainable params: 42,626,560
# _________________________________________________________________

# %%
# Compile the Neural network
opt = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

filepath = 'model_Batik.h5'
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience= 10)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint, es]

# %%
#save the model history in a list after fitting so taht we can plot later
model_history = []
history = model.fit(
        train_generator,
        validation_data=validation_generator,
        batch_size=64,
        epochs=100,
        callbacks=[checkpoint, es])

# Evaluasi model pada data pelatihan
train_score = model.evaluate(train_generator)
print('Train Score:', train_score)

val_score = model.evaluate(validation_generator)
print('Val Score:', val_score)

test_score = model.evaluate(test_set)
print('Test Score:', test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1861: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1871: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7209 - accuracy: 0.3200
# Epoch 1: val_loss improved from inf to 1.40547, saving model to model_Batik.h5
# 38/38 [==============================] - 574s 15s/step - loss: 1.7209 - accuracy: 0.3200 - val_loss: 1.4055 - val_accuracy: 0.4050
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1527 - accuracy: 0.6375
# Epoch 2: val_loss improved from 1.40547 to 1.09211, saving model to model_Batik.h5
# 38/38 [==============================] - 28s 722ms/step - loss: 1.1527 - accuracy: 0.6375 - val_loss: 1.0921 - val_accuracy: 0.6317
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8072 - accuracy: 0.8167
# Epoch 3: val_loss improved from 1.09211 to 0.92863, saving model to model_Batik.h5
# 38/38 [==============================] - 28s 726ms/step - loss: 0.8072 - accuracy: 0.8167 - val_loss: 0.9286 - val_accuracy: 0.6750
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5925 - accuracy: 0.8825
# Epoch 4: val_loss improved from 0.92863 to 0.79593, saving model to model_Batik.h5
# 38/38 [==============================] - 28s 740ms/step - loss: 0.5925 - accuracy: 0.8825 - val_loss: 0.7959 - val_accuracy: 0.7183
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4588 - accuracy: 0.9204
# Epoch 5: val_loss improved from 0.79593 to 0.66967, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 750ms/step - loss: 0.4588 - accuracy: 0.9204 - val_loss: 0.6697 - val_accuracy: 0.7733
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.9358
# Epoch 6: val_loss improved from 0.66967 to 0.57929, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 749ms/step - loss: 0.3623 - accuracy: 0.9358 - val_loss: 0.5793 - val_accuracy: 0.8117
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9483
# Epoch 7: val_loss improved from 0.57929 to 0.57041, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 757ms/step - loss: 0.2871 - accuracy: 0.9483 - val_loss: 0.5704 - val_accuracy: 0.7900
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9583
# Epoch 8: val_loss improved from 0.57041 to 0.55457, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 751ms/step - loss: 0.2334 - accuracy: 0.9583 - val_loss: 0.5546 - val_accuracy: 0.8067
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.9679
# Epoch 9: val_loss improved from 0.55457 to 0.51442, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 755ms/step - loss: 0.1951 - accuracy: 0.9679 - val_loss: 0.5144 - val_accuracy: 0.8233
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9737
# Epoch 10: val_loss improved from 0.51442 to 0.49250, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 766ms/step - loss: 0.1631 - accuracy: 0.9737 - val_loss: 0.4925 - val_accuracy: 0.8133
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9754
# Epoch 11: val_loss improved from 0.49250 to 0.48050, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 738ms/step - loss: 0.1426 - accuracy: 0.9754 - val_loss: 0.4805 - val_accuracy: 0.8083
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9825
# Epoch 12: val_loss improved from 0.48050 to 0.41346, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 750ms/step - loss: 0.1224 - accuracy: 0.9825 - val_loss: 0.4135 - val_accuracy: 0.8450
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9879
# Epoch 13: val_loss did not improve from 0.41346
# 38/38 [==============================] - 33s 857ms/step - loss: 0.0995 - accuracy: 0.9879 - val_loss: 0.4391 - val_accuracy: 0.8500
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9879
# Epoch 14: val_loss did not improve from 0.41346
# 38/38 [==============================] - 28s 722ms/step - loss: 0.0912 - accuracy: 0.9879 - val_loss: 0.4278 - val_accuracy: 0.8450
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9892
# Epoch 15: val_loss did not improve from 0.41346
# 38/38 [==============================] - 29s 747ms/step - loss: 0.0745 - accuracy: 0.9892 - val_loss: 0.4762 - val_accuracy: 0.8400
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9900
# Epoch 16: val_loss improved from 0.41346 to 0.40560, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 750ms/step - loss: 0.0715 - accuracy: 0.9900 - val_loss: 0.4056 - val_accuracy: 0.8383
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9937
# Epoch 17: val_loss did not improve from 0.40560
# 38/38 [==============================] - 28s 734ms/step - loss: 0.0584 - accuracy: 0.9937 - val_loss: 0.4386 - val_accuracy: 0.8433
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9954
# Epoch 18: val_loss did not improve from 0.40560
# 38/38 [==============================] - 28s 738ms/step - loss: 0.0498 - accuracy: 0.9954 - val_loss: 0.4206 - val_accuracy: 0.8583
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9954
# Epoch 19: val_loss did not improve from 0.40560
# 38/38 [==============================] - 28s 740ms/step - loss: 0.0483 - accuracy: 0.9954 - val_loss: 0.4410 - val_accuracy: 0.8433
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9967
# Epoch 20: val_loss did not improve from 0.40560
# 38/38 [==============================] - 29s 749ms/step - loss: 0.0399 - accuracy: 0.9967 - val_loss: 0.4175 - val_accuracy: 0.8450
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9971
# Epoch 21: val_loss improved from 0.40560 to 0.39329, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 749ms/step - loss: 0.0387 - accuracy: 0.9971 - val_loss: 0.3933 - val_accuracy: 0.8650
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9983
# Epoch 22: val_loss did not improve from 0.39329
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0329 - accuracy: 0.9983 - val_loss: 0.3998 - val_accuracy: 0.8617
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9967
# Epoch 23: val_loss did not improve from 0.39329
# 38/38 [==============================] - 28s 724ms/step - loss: 0.0287 - accuracy: 0.9967 - val_loss: 0.3942 - val_accuracy: 0.8617
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9987
# Epoch 24: val_loss did not improve from 0.39329
# 38/38 [==============================] - 27s 718ms/step - loss: 0.0261 - accuracy: 0.9987 - val_loss: 0.4119 - val_accuracy: 0.8633
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9979
# Epoch 25: val_loss did not improve from 0.39329
# 38/38 [==============================] - 28s 735ms/step - loss: 0.0246 - accuracy: 0.9979 - val_loss: 0.4032 - val_accuracy: 0.8700
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9987
# Epoch 26: val_loss did not improve from 0.39329
# 38/38 [==============================] - 28s 713ms/step - loss: 0.0221 - accuracy: 0.9987 - val_loss: 0.4008 - val_accuracy: 0.8717
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9987
# Epoch 27: val_loss did not improve from 0.39329
# 38/38 [==============================] - 28s 723ms/step - loss: 0.0207 - accuracy: 0.9987 - val_loss: 0.4054 - val_accuracy: 0.8683
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9987
# Epoch 28: val_loss did not improve from 0.39329
# 38/38 [==============================] - 27s 713ms/step - loss: 0.0177 - accuracy: 0.9987 - val_loss: 0.4024 - val_accuracy: 0.8650
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9987
# Epoch 29: val_loss improved from 0.39329 to 0.38475, saving model to model_Batik.h5
# 38/38 [==============================] - 29s 746ms/step - loss: 0.0171 - accuracy: 0.9987 - val_loss: 0.3847 - val_accuracy: 0.8683
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9996
# Epoch 30: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 729ms/step - loss: 0.0144 - accuracy: 0.9996 - val_loss: 0.4038 - val_accuracy: 0.8700
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9992
# Epoch 31: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 724ms/step - loss: 0.0135 - accuracy: 0.9992 - val_loss: 0.3913 - val_accuracy: 0.8750
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9992
# Epoch 32: val_loss did not improve from 0.38475
# 38/38 [==============================] - 27s 718ms/step - loss: 0.0119 - accuracy: 0.9992 - val_loss: 0.4037 - val_accuracy: 0.8800
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9996
# Epoch 33: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 729ms/step - loss: 0.0113 - accuracy: 0.9996 - val_loss: 0.3980 - val_accuracy: 0.8783
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.38475
# 38/38 [==============================] - 32s 848ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.8783
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9996
# Epoch 35: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 735ms/step - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.4090 - val_accuracy: 0.8750
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9996
# Epoch 36: val_loss did not improve from 0.38475
# 38/38 [==============================] - 27s 713ms/step - loss: 0.0078 - accuracy: 0.9996 - val_loss: 0.4234 - val_accuracy: 0.8733
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9996
# Epoch 37: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 730ms/step - loss: 0.0086 - accuracy: 0.9996 - val_loss: 0.4351 - val_accuracy: 0.8817
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.38475
# 38/38 [==============================] - 28s 721ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8767
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9996
# Epoch 39: val_loss did not improve from 0.38475
# 38/38 [==============================] - 27s 720ms/step - loss: 0.0069 - accuracy: 0.9996 - val_loss: 0.4334 - val_accuracy: 0.8767
# Epoch 39: early stopping
# 38/38 [==============================] - 22s 583ms/step - loss: 0.0056 - accuracy: 0.9996
# Train Score: [0.005570631008595228, 0.9995833039283752]
# 10/10 [==============================] - 6s 585ms/step - loss: 0.4334 - accuracy: 0.8767
# Val Score: [0.43338334560394287, 0.8766666650772095]
# 5/5 [==============================] - 58s 14s/step - loss: 0.5303 - accuracy: 0.8333
# Test Score: [0.5302767157554626, 0.8333333134651184]

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Prediksi label menggunakan model
y_pred = model.predict_generator(test_set, steps=len(test_set))

# Ambil label yang sebenarnya
y_true = test_set.classes
# Out:
# <ipython-input-16-bb0447526716>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_set, steps=len(test_set))

# %%
# Hitung confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
print(conf_matrix)

# # plot confusion matrix
# plt.imshow(conf_matrix, cmap=plt.cm.Blues)
# plt.title('Confusion Matrix')

df_cm = pd.DataFrame(conf_matrix, index= test_set.class_indices, columns= test_set.class_indices)

# plot confusion matrix using seaborn heatmap
sns.heatmap(df_cm, annot=True, fmt= 'd')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()
# Out:
# [[22  5  4  0  0 19]
#  [ 0 50  0  0  0  0]
#  [ 0  0 50  0  0  0]
#  [13  3  0 32  2  0]
#  [ 0  0  4  0 46  0]
#  [ 0  0  0  0  0 50]]

# %%
# Step 1: Predict on test data
y_pred_prob = model.predict_generator(test_set)

# Step 2: Get class with highest probability
y_pred = np.argmax(y_pred_prob, axis=1)

# Step 3: Calculate accuracy score
from sklearn.metrics import accuracy_score
y_true = test_set.classes
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# <ipython-input-18-4c125e6a6fc1>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_prob = model.predict_generator(test_set)
# Accuracy: 0.8333333333333334

# %%
# membuat classification report
from sklearn.metrics import classification_report
report = classification_report(y_true, y_pred, target_names=test_set.class_indices)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       CEPLOK       0.63      0.44      0.52        50
#       KAWUNG       0.86      1.00      0.93        50
#  MEGAMENDUNG       0.86      1.00      0.93        50
#        NITIK       1.00      0.64      0.78        50
#       PARANG       0.96      0.92      0.94        50
#       TAMBAL       0.72      1.00      0.84        50
#
#     accuracy                           0.83       300
#    macro avg       0.84      0.83      0.82       300
# weighted avg       0.84      0.83      0.82       300

# %%
from PIL import Image
import numpy as np
from keras.models import load_model


classes = ['Ceplok', 'Kawung', 'Megamendung', 'Nitik', 'Parang', 'Tambal']
loaded_model = load_model ('model_Batik.h5')

image_testing = Image.open('/content/drive/MyDrive/ROTATION AUG BATIK/DATA TEST/TAMBAL/NonGMB_Aug__0_265.jpg')
image_testing = np.array(image_testing.resize((300, 300)))/255.0
plt.imshow(image_testing)
image_testing.shape

image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)

output = model.predict(image_testing)
best_index = np.argmax(output)
class_name = classes[best_index]

print(output)
print(best_index)

print(classes[best_index])
# Out:
# (1, 300, 300, 3)
# 1/1 [==============================] - 2s 2s/step
# [[1.2403109e-06 5.7510729e-06 5.3094104e-06 8.2625802e-06 1.5806495e-06
#   9.9997783e-01]]
# 5
# Tambal
