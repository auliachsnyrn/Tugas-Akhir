# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. If you're inspired to dig deeper, click the blue "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first import libraries and define functions for plotting the data using `matplotlib`. Depending on the data, not all plots will be made. (Hey, I'm just a simple kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There is 0 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/BATIKK/Batik Parang/87.jpg
# /kaggle/input/BATIKK/Batik Parang/38.jpg
# /kaggle/input/BATIKK/Batik Parang/99.jpg
# /kaggle/input/BATIKK/Batik Parang/90.jpg
# /kaggle/input/BATIKK/Batik Parang/76.jpg
# /kaggle/input/BATIKK/Batik Parang/73.jpg
# /kaggle/input/BATIKK/Batik Parang/97.jpg
# /kaggle/input/BATIKK/Batik Parang/49.jpeg
# /kaggle/input/BATIKK/Batik Parang/42.jpg
# /kaggle/input/BATIKK/Batik Parang/48.jpg
# /kaggle/input/BATIKK/Batik Parang/75.jpg
# /kaggle/input/BATIKK/Batik Parang/64.jpg
# /kaggle/input/BATIKK/Batik Parang/26.jpg
# /kaggle/input/BATIKK/Batik Parang/13.jpg
# /kaggle/input/BATIKK/Batik Parang/91.jpg
# /kaggle/input/BATIKK/Batik Parang/71.jpg
# /kaggle/input/BATIKK/Batik Parang/83.jpg
# /kaggle/input/BATIKK/Batik Parang/12.jpg
# /kaggle/input/BATIKK/Batik Parang/59.jpg
# /kaggle/input/BATIKK/Batik Parang/43.jpg
# /kaggle/input/BATIKK/Batik Parang/2.jpg
# /kaggle/input/BATIKK/Batik Parang/92.jpg
# /kaggle/input/BATIKK/Batik Parang/33.jpg
# /kaggle/input/BATIKK/Batik Parang/85.jpg
# /kaggle/input/BATIKK/Batik Parang/100.jpg
# /kaggle/input/BATIKK/Batik Parang/21.jpg
# /kaggle/input/BATIKK/Batik Parang/95.jpg
# /kaggle/input/BATIKK/Batik Parang/25.jpg
# /kaggle/input/BATIKK/Batik Parang/61.jpg
# /kaggle/input/BATIKK/Batik Parang/96.jpg
# /kaggle/input/BATIKK/Batik Parang/10.jpg
# /kaggle/input/BATIKK/Batik Parang/53.jpg
# /kaggle/input/BATIKK/Batik Parang/81.jpg
# /kaggle/input/BATIKK/Batik Parang/79.jpg
# /kaggle/input/BATIKK/Batik Parang/40.jpg
# /kaggle/input/BATIKK/Batik Parang/84.jpg
# /kaggle/input/BATIKK/Batik Parang/67.jpg
# /kaggle/input/BATIKK/Batik Parang/89.jpg
# /kaggle/input/BATIKK/Batik Parang/82.jpg
# /kaggle/input/BATIKK/Batik Parang/9.jpg
# /kaggle/input/BATIKK/Batik Parang/34.jpg
# /kaggle/input/BATIKK/Batik Parang/18.jpg
# /kaggle/input/BATIKK/Batik Parang/45.jpg
# /kaggle/input/BATIKK/Batik Parang/11.jpg
# /kaggle/input/BATIKK/Batik Parang/52.jpeg
# /kaggle/input/BATIKK/Batik Parang/20.jpg
# /kaggle/input/BATIKK/Batik Parang/56.jpg
# /kaggle/input/BATIKK/Batik Parang/54.jpg
# /kaggle/input/BATIKK/Batik Parang/72.png
# /kaggle/input/BATIKK/Batik Parang/22.jpg
# /kaggle/input/BATIKK/Batik Parang/86.jpg
# /kaggle/input/BATIKK/Batik Parang/1.jpg
# /kaggle/input/BATIKK/Batik Parang/15.jpg
# /kaggle/input/BATIKK/Batik Parang/63.jpg
# /kaggle/input/BATIKK/Batik Parang/58.jpg
# /kaggle/input/BATIKK/Batik Parang/77.jpg
# /kaggle/input/BATIKK/Batik Parang/88.jpg
# /kaggle/input/BATIKK/Batik Parang/78.jpg
# /kaggle/input/BATIKK/Batik Parang/68.jpg
# /kaggle/input/BATIKK/Batik Parang/17.jpg
# /kaggle/input/BATIKK/Batik Parang/35.jpg
# /kaggle/input/BATIKK/Batik Parang/70.jpg
# /kaggle/input/BATIKK/Batik Parang/44.jpg
# /kaggle/input/BATIKK/Batik Parang/23.jpg
# /kaggle/input/BATIKK/Batik Parang/55.jpg
# /kaggle/input/BATIKK/Batik Parang/46.jpg
# /kaggle/input/BATIKK/Batik Parang/69.png
# /kaggle/input/BATIKK/Batik Parang/31.jpg
# /kaggle/input/BATIKK/Batik Parang/94.jpg
# /kaggle/input/BATIKK/Batik Parang/3.jpg
# /kaggle/input/BATIKK/Batik Parang/57.jpg
# /kaggle/input/BATIKK/Batik Parang/37.jpg
# /kaggle/input/BATIKK/Batik Parang/8.jpg
# /kaggle/input/BATIKK/Batik Parang/30.png
# /kaggle/input/BATIKK/Batik Parang/65.jpg
# /kaggle/input/BATIKK/Batik Parang/98.jpg
# /kaggle/input/BATIKK/Batik Parang/7.jpg
# /kaggle/input/BATIKK/Batik Parang/6.jpeg
# /kaggle/input/BATIKK/Batik Parang/60.jpg
# /kaggle/input/BATIKK/Batik Parang/14.jpg
# /kaggle/input/BATIKK/Batik Parang/66.jpg
# /kaggle/input/BATIKK/Batik Parang/4.jpg
# /kaggle/input/BATIKK/Batik Parang/28.jpg
# /kaggle/input/BATIKK/Batik Parang/47.jpg
# /kaggle/input/BATIKK/Batik Parang/19.jpg
# /kaggle/input/BATIKK/Batik Parang/93.jpg
# /kaggle/input/BATIKK/Batik Parang/62.jpg
# /kaggle/input/BATIKK/Batik Parang/5.jpg
# /kaggle/input/BATIKK/Batik Parang/51.jpeg
# /kaggle/input/BATIKK/Batik Parang/50.jpeg
# /kaggle/input/BATIKK/Batik Parang/16.jpg
# /kaggle/input/BATIKK/Batik Parang/24.png
# /kaggle/input/BATIKK/Batik Parang/29.png
# /kaggle/input/BATIKK/Batik Parang/41.jpg
# /kaggle/input/BATIKK/Batik Parang/27.jpg
# /kaggle/input/BATIKK/Batik Parang/80.jpg
# /kaggle/input/BATIKK/Batik Parang/39.jpg
# /kaggle/input/BATIKK/Batik Parang/74.jpg
# /kaggle/input/BATIKK/Batik Parang/32.jpg
# /kaggle/input/BATIKK/Batik Parang/36.jpg
# /kaggle/input/BATIKK/Batik Ceplok/87.jpg
# /kaggle/input/BATIKK/Batik Ceplok/100.png
# /kaggle/input/BATIKK/Batik Ceplok/99.jpg
# /kaggle/input/BATIKK/Batik Ceplok/90.jpg
# /kaggle/input/BATIKK/Batik Ceplok/76.jpg
# /kaggle/input/BATIKK/Batik Ceplok/73.jpg
# /kaggle/input/BATIKK/Batik Ceplok/97.jpg
# /kaggle/input/BATIKK/Batik Ceplok/42.jpg
# /kaggle/input/BATIKK/Batik Ceplok/49.jpg
# /kaggle/input/BATIKK/Batik Ceplok/48.jpg
# /kaggle/input/BATIKK/Batik Ceplok/28.JPG
# /kaggle/input/BATIKK/Batik Ceplok/75.jpg
# /kaggle/input/BATIKK/Batik Ceplok/64.jpg
# /kaggle/input/BATIKK/Batik Ceplok/26.jpg
# /kaggle/input/BATIKK/Batik Ceplok/36.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/69.jpg
# /kaggle/input/BATIKK/Batik Ceplok/13.jpg
# /kaggle/input/BATIKK/Batik Ceplok/17.png
# /kaggle/input/BATIKK/Batik Ceplok/91.jpg
# /kaggle/input/BATIKK/Batik Ceplok/71.jpg
# /kaggle/input/BATIKK/Batik Ceplok/83.jpg
# /kaggle/input/BATIKK/Batik Ceplok/12.jpg
# /kaggle/input/BATIKK/Batik Ceplok/33.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/59.jpg
# /kaggle/input/BATIKK/Batik Ceplok/43.jpg
# /kaggle/input/BATIKK/Batik Ceplok/92.jpg
# /kaggle/input/BATIKK/Batik Ceplok/85.jpg
# /kaggle/input/BATIKK/Batik Ceplok/24.jpg
# /kaggle/input/BATIKK/Batik Ceplok/21.jpg
# /kaggle/input/BATIKK/Batik Ceplok/95.jpg
# /kaggle/input/BATIKK/Batik Ceplok/25.jpg
# /kaggle/input/BATIKK/Batik Ceplok/61.jpg
# /kaggle/input/BATIKK/Batik Ceplok/1.png
# /kaggle/input/BATIKK/Batik Ceplok/96.jpg
# /kaggle/input/BATIKK/Batik Ceplok/10.jpg
# /kaggle/input/BATIKK/Batik Ceplok/37.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/53.jpg
# /kaggle/input/BATIKK/Batik Ceplok/81.jpg
# /kaggle/input/BATIKK/Batik Ceplok/79.jpg
# /kaggle/input/BATIKK/Batik Ceplok/32.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/35.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/86.png
# /kaggle/input/BATIKK/Batik Ceplok/84.jpg
# /kaggle/input/BATIKK/Batik Ceplok/30.jpg
# /kaggle/input/BATIKK/Batik Ceplok/89.jpg
# /kaggle/input/BATIKK/Batik Ceplok/82.jpg
# /kaggle/input/BATIKK/Batik Ceplok/9.jpg
# /kaggle/input/BATIKK/Batik Ceplok/34.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/72.jpg
# /kaggle/input/BATIKK/Batik Ceplok/45.jpg
# /kaggle/input/BATIKK/Batik Ceplok/11.jpg
# /kaggle/input/BATIKK/Batik Ceplok/50.jpg
# /kaggle/input/BATIKK/Batik Ceplok/20.jpg
# /kaggle/input/BATIKK/Batik Ceplok/56.jpg
# /kaggle/input/BATIKK/Batik Ceplok/54.jpg
# /kaggle/input/BATIKK/Batik Ceplok/22.jpg
# /kaggle/input/BATIKK/Batik Ceplok/67.png
# /kaggle/input/BATIKK/Batik Ceplok/15.jpg
# /kaggle/input/BATIKK/Batik Ceplok/63.jpg
# /kaggle/input/BATIKK/Batik Ceplok/58.jpg
# /kaggle/input/BATIKK/Batik Ceplok/77.jpg
# /kaggle/input/BATIKK/Batik Ceplok/29.jpg
# /kaggle/input/BATIKK/Batik Ceplok/88.jpg
# /kaggle/input/BATIKK/Batik Ceplok/78.jpg
# /kaggle/input/BATIKK/Batik Ceplok/68.jpg
# /kaggle/input/BATIKK/Batik Ceplok/51.jpg
# /kaggle/input/BATIKK/Batik Ceplok/70.jpg
# /kaggle/input/BATIKK/Batik Ceplok/2.png
# /kaggle/input/BATIKK/Batik Ceplok/44.jpg
# /kaggle/input/BATIKK/Batik Ceplok/23.jpg
# /kaggle/input/BATIKK/Batik Ceplok/18.png
# /kaggle/input/BATIKK/Batik Ceplok/55.jpg
# /kaggle/input/BATIKK/Batik Ceplok/46.jpg
# /kaggle/input/BATIKK/Batik Ceplok/31.jpg
# /kaggle/input/BATIKK/Batik Ceplok/66.png
# /kaggle/input/BATIKK/Batik Ceplok/94.jpg
# /kaggle/input/BATIKK/Batik Ceplok/3.jpg
# /kaggle/input/BATIKK/Batik Ceplok/57.jpg
# /kaggle/input/BATIKK/Batik Ceplok/8.jpg
# /kaggle/input/BATIKK/Batik Ceplok/40.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/38.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/39.jpeg
# /kaggle/input/BATIKK/Batik Ceplok/98.jpg
# /kaggle/input/BATIKK/Batik Ceplok/7.jpg
# /kaggle/input/BATIKK/Batik Ceplok/60.jpg
# /kaggle/input/BATIKK/Batik Ceplok/14.jpg
# /kaggle/input/BATIKK/Batik Ceplok/4.jpg
# /kaggle/input/BATIKK/Batik Ceplok/47.jpg
# /kaggle/input/BATIKK/Batik Ceplok/19.jpg
# /kaggle/input/BATIKK/Batik Ceplok/93.jpg
# /kaggle/input/BATIKK/Batik Ceplok/62.jpg
# /kaggle/input/BATIKK/Batik Ceplok/5.jpg
# /kaggle/input/BATIKK/Batik Ceplok/6.jpg
# /kaggle/input/BATIKK/Batik Ceplok/16.jpg
# /kaggle/input/BATIKK/Batik Ceplok/65.png
# /kaggle/input/BATIKK/Batik Ceplok/52.jpg
# /kaggle/input/BATIKK/Batik Ceplok/41.jpg
# /kaggle/input/BATIKK/Batik Ceplok/27.jpg
# /kaggle/input/BATIKK/Batik Ceplok/80.jpg
# /kaggle/input/BATIKK/Batik Ceplok/74.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/38.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/99.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/90.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/76.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/73.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/97.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/49.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/48.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/75.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/64.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/26.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/68.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/69.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/13.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/17.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/91.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/44.jpeg
# /kaggle/input/BATIKK/Batik Sekar Jagad/71.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/83.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/12.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/59.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/43.jpeg
# /kaggle/input/BATIKK/Batik Sekar Jagad/2.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/92.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/85.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/100.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/24.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/21.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/95.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/25.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/61.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/96.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/10.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/53.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/81.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/79.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/40.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/84.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/67.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/89.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/82.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/9.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/34.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/72.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/18.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/45.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/11.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/87.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/50.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/20.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/56.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/54.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/22.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/86.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/1.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/15.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/63.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/58.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/77.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/29.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/88.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/78.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/35.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/51.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/70.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/33.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/55.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/46.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/31.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/94.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/3.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/57.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/37.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/8.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/30.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/42.jpeg
# /kaggle/input/BATIKK/Batik Sekar Jagad/65.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/98.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/7.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/60.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/14.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/66.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/4.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/28.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/47.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/19.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/93.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/62.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/23.png
# /kaggle/input/BATIKK/Batik Sekar Jagad/5.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/6.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/16.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/52.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/41.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/27.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/80.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/39.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/74.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/32.jpg
# /kaggle/input/BATIKK/Batik Sekar Jagad/36.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/87.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/38.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/99.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/90.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/79.png
# /kaggle/input/BATIKK/Batik Udan Liris/83.gif
# /kaggle/input/BATIKK/Batik Udan Liris/76.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/73.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/97.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/42.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/49.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/48.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/75.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/64.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/26.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/69.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/17.png
# /kaggle/input/BATIKK/Batik Udan Liris/91.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/71.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/12.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/33.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/59.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/43.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/2.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/31.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/92.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/85.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/100.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/24.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/21.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/84.gif
# /kaggle/input/BATIKK/Batik Udan Liris/95.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/25.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/61.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/96.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/10.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/53.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/81.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/32.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/40.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/67.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/89.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/82.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/23.gif
# /kaggle/input/BATIKK/Batik Udan Liris/34.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/72.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/18.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/45.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/11.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/50.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/30.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/20.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/56.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/54.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/22.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/86.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/1.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/15.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/63.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/58.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/77.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/29.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/88.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/78.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/68.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/9.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/35.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/51.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/70.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/44.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/55.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/46.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/94.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/3.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/13.jpeg
# /kaggle/input/BATIKK/Batik Udan Liris/57.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/37.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/8.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/65.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/98.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/7.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/60.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/14.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/66.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/4.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/28.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/47.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/19.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/93.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/62.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/5.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/16.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/52.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/41.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/27.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/80.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/39.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/6.png
# /kaggle/input/BATIKK/Batik Udan Liris/74.jpg
# /kaggle/input/BATIKK/Batik Udan Liris/36.jpg
# /kaggle/input/BATIKK/Batik Nitik/87.jpg
# /kaggle/input/BATIKK/Batik Nitik/38.jpg
# /kaggle/input/BATIKK/Batik Nitik/99.jpg
# /kaggle/input/BATIKK/Batik Nitik/90.jpg
# /kaggle/input/BATIKK/Batik Nitik/76.jpg
# /kaggle/input/BATIKK/Batik Nitik/73.jpg
# /kaggle/input/BATIKK/Batik Nitik/97.jpg
# /kaggle/input/BATIKK/Batik Nitik/42.jpg
# /kaggle/input/BATIKK/Batik Nitik/49.jpg
# /kaggle/input/BATIKK/Batik Nitik/48.jpg
# /kaggle/input/BATIKK/Batik Nitik/75.jpg
# /kaggle/input/BATIKK/Batik Nitik/64.jpg
# /kaggle/input/BATIKK/Batik Nitik/26.jpg
# /kaggle/input/BATIKK/Batik Nitik/69.jpg
# /kaggle/input/BATIKK/Batik Nitik/13.jpg
# /kaggle/input/BATIKK/Batik Nitik/91.jpg
# /kaggle/input/BATIKK/Batik Nitik/71.jpg
# /kaggle/input/BATIKK/Batik Nitik/83.jpg
# /kaggle/input/BATIKK/Batik Nitik/12.jpg
# /kaggle/input/BATIKK/Batik Nitik/59.jpg
# /kaggle/input/BATIKK/Batik Nitik/43.jpg
# /kaggle/input/BATIKK/Batik Nitik/2.jpg
# /kaggle/input/BATIKK/Batik Nitik/92.jpg
# /kaggle/input/BATIKK/Batik Nitik/33.jpg
# /kaggle/input/BATIKK/Batik Nitik/85.jpg
# /kaggle/input/BATIKK/Batik Nitik/100.jpg
# /kaggle/input/BATIKK/Batik Nitik/24.jpg
# /kaggle/input/BATIKK/Batik Nitik/21.jpg
# /kaggle/input/BATIKK/Batik Nitik/95.jpg
# /kaggle/input/BATIKK/Batik Nitik/25.jpg
# /kaggle/input/BATIKK/Batik Nitik/61.jpg
# /kaggle/input/BATIKK/Batik Nitik/96.jpg
# /kaggle/input/BATIKK/Batik Nitik/10.jpg
# /kaggle/input/BATIKK/Batik Nitik/53.jpg
# /kaggle/input/BATIKK/Batik Nitik/81.jpg
# /kaggle/input/BATIKK/Batik Nitik/79.jpg
# /kaggle/input/BATIKK/Batik Nitik/40.jpg
# /kaggle/input/BATIKK/Batik Nitik/84.jpg
# /kaggle/input/BATIKK/Batik Nitik/19.JPG
# /kaggle/input/BATIKK/Batik Nitik/67.jpg
# /kaggle/input/BATIKK/Batik Nitik/30.jpg
# /kaggle/input/BATIKK/Batik Nitik/89.jpg
# /kaggle/input/BATIKK/Batik Nitik/82.jpg
# /kaggle/input/BATIKK/Batik Nitik/9.jpg
# /kaggle/input/BATIKK/Batik Nitik/34.jpg
# /kaggle/input/BATIKK/Batik Nitik/72.jpg
# /kaggle/input/BATIKK/Batik Nitik/18.jpg
# /kaggle/input/BATIKK/Batik Nitik/45.jpg
# /kaggle/input/BATIKK/Batik Nitik/50.jpg
# /kaggle/input/BATIKK/Batik Nitik/20.jpg
# /kaggle/input/BATIKK/Batik Nitik/56.jpg
# /kaggle/input/BATIKK/Batik Nitik/54.jpg
# /kaggle/input/BATIKK/Batik Nitik/86.jpg
# /kaggle/input/BATIKK/Batik Nitik/1.jpg
# /kaggle/input/BATIKK/Batik Nitik/11.JPG
# /kaggle/input/BATIKK/Batik Nitik/15.jpg
# /kaggle/input/BATIKK/Batik Nitik/63.jpg
# /kaggle/input/BATIKK/Batik Nitik/58.jpg
# /kaggle/input/BATIKK/Batik Nitik/77.jpg
# /kaggle/input/BATIKK/Batik Nitik/29.jpg
# /kaggle/input/BATIKK/Batik Nitik/88.jpg
# /kaggle/input/BATIKK/Batik Nitik/78.jpg
# /kaggle/input/BATIKK/Batik Nitik/68.jpg
# /kaggle/input/BATIKK/Batik Nitik/17.jpg
# /kaggle/input/BATIKK/Batik Nitik/35.jpg
# /kaggle/input/BATIKK/Batik Nitik/51.jpg
# /kaggle/input/BATIKK/Batik Nitik/70.jpg
# /kaggle/input/BATIKK/Batik Nitik/44.jpg
# /kaggle/input/BATIKK/Batik Nitik/23.jpg
# /kaggle/input/BATIKK/Batik Nitik/55.jpg
# /kaggle/input/BATIKK/Batik Nitik/46.jpg
# /kaggle/input/BATIKK/Batik Nitik/31.jpg
# /kaggle/input/BATIKK/Batik Nitik/94.jpg
# /kaggle/input/BATIKK/Batik Nitik/3.jpg
# /kaggle/input/BATIKK/Batik Nitik/57.jpg
# /kaggle/input/BATIKK/Batik Nitik/37.jpg
# /kaggle/input/BATIKK/Batik Nitik/8.jpg
# /kaggle/input/BATIKK/Batik Nitik/65.jpg
# /kaggle/input/BATIKK/Batik Nitik/98.jpg
# /kaggle/input/BATIKK/Batik Nitik/7.jpg
# /kaggle/input/BATIKK/Batik Nitik/60.jpg
# /kaggle/input/BATIKK/Batik Nitik/14.jpg
# /kaggle/input/BATIKK/Batik Nitik/66.jpg
# /kaggle/input/BATIKK/Batik Nitik/4.jpg
# /kaggle/input/BATIKK/Batik Nitik/28.jpg
# /kaggle/input/BATIKK/Batik Nitik/47.jpg
# /kaggle/input/BATIKK/Batik Nitik/93.jpg
# /kaggle/input/BATIKK/Batik Nitik/62.jpg
# /kaggle/input/BATIKK/Batik Nitik/22.JPG
# /kaggle/input/BATIKK/Batik Nitik/5.jpg
# /kaggle/input/BATIKK/Batik Nitik/6.jpg
# /kaggle/input/BATIKK/Batik Nitik/16.jpg
# /kaggle/input/BATIKK/Batik Nitik/52.jpg
# /kaggle/input/BATIKK/Batik Nitik/41.jpg
# /kaggle/input/BATIKK/Batik Nitik/27.jpg
# /kaggle/input/BATIKK/Batik Nitik/80.jpg
# /kaggle/input/BATIKK/Batik Nitik/39.jpg
# /kaggle/input/BATIKK/Batik Nitik/74.jpg
# /kaggle/input/BATIKK/Batik Nitik/32.jpg
# /kaggle/input/BATIKK/Batik Nitik/36.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/87.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/38.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/90.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/73.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/97.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/42.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/49.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/48.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/75.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/64.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/26.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/99.jpeg
# /kaggle/input/BATIKK/Batik Sidomukti/69.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/91.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/71.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/83.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/3.png
# /kaggle/input/BATIKK/Batik Sidomukti/59.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/43.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/92.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/33.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/100.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/24.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/52.png
# /kaggle/input/BATIKK/Batik Sidomukti/21.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/76.JPG
# /kaggle/input/BATIKK/Batik Sidomukti/95.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/25.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/61.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/96.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/10.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/13.png
# /kaggle/input/BATIKK/Batik Sidomukti/81.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/53.png
# /kaggle/input/BATIKK/Batik Sidomukti/79.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/35.jpeg
# /kaggle/input/BATIKK/Batik Sidomukti/40.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/84.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/67.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/30.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/89.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/82.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/9.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/34.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/72.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/18.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/45.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/11.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/50.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/20.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/56.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/54.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/22.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/86.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/85.jpeg
# /kaggle/input/BATIKK/Batik Sidomukti/1.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/15.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/63.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/58.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/77.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/29.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/88.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/78.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/68.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/17.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/51.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/70.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/2.png
# /kaggle/input/BATIKK/Batik Sidomukti/44.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/23.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/55.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/46.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/31.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/94.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/57.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/37.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/8.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/65.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/39.jpeg
# /kaggle/input/BATIKK/Batik Sidomukti/98.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/7.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/60.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/14.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/66.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/4.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/28.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/47.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/19.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/93.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/62.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/5.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/16.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/12.png
# /kaggle/input/BATIKK/Batik Sidomukti/41.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/27.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/80.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/6.png
# /kaggle/input/BATIKK/Batik Sidomukti/74.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/32.jpg
# /kaggle/input/BATIKK/Batik Sidomukti/36.jpg
# /kaggle/input/BATIKK/Batik Truntum/87.jpg
# /kaggle/input/BATIKK/Batik Truntum/99.jpg
# /kaggle/input/BATIKK/Batik Truntum/90.jpg
# /kaggle/input/BATIKK/Batik Truntum/76.jpg
# /kaggle/input/BATIKK/Batik Truntum/97.jpg
# /kaggle/input/BATIKK/Batik Truntum/42.jpg
# /kaggle/input/BATIKK/Batik Truntum/49.jpg
# /kaggle/input/BATIKK/Batik Truntum/48.jpg
# /kaggle/input/BATIKK/Batik Truntum/64.jpg
# /kaggle/input/BATIKK/Batik Truntum/26.jpg
# /kaggle/input/BATIKK/Batik Truntum/69.jpg
# /kaggle/input/BATIKK/Batik Truntum/13.jpg
# /kaggle/input/BATIKK/Batik Truntum/91.jpg
# /kaggle/input/BATIKK/Batik Truntum/71.jpg
# /kaggle/input/BATIKK/Batik Truntum/83.jpg
# /kaggle/input/BATIKK/Batik Truntum/12.jpg
# /kaggle/input/BATIKK/Batik Truntum/59.jpg
# /kaggle/input/BATIKK/Batik Truntum/2.jpg
# /kaggle/input/BATIKK/Batik Truntum/38.png
# /kaggle/input/BATIKK/Batik Truntum/92.jpg
# /kaggle/input/BATIKK/Batik Truntum/33.jpg
# /kaggle/input/BATIKK/Batik Truntum/85.jpg
# /kaggle/input/BATIKK/Batik Truntum/100.jpg
# /kaggle/input/BATIKK/Batik Truntum/24.jpg
# /kaggle/input/BATIKK/Batik Truntum/21.jpg
# /kaggle/input/BATIKK/Batik Truntum/95.jpg
# /kaggle/input/BATIKK/Batik Truntum/25.jpg
# /kaggle/input/BATIKK/Batik Truntum/61.jpg
# /kaggle/input/BATIKK/Batik Truntum/96.jpg
# /kaggle/input/BATIKK/Batik Truntum/53.jpg
# /kaggle/input/BATIKK/Batik Truntum/81.jpg
# /kaggle/input/BATIKK/Batik Truntum/79.jpg
# /kaggle/input/BATIKK/Batik Truntum/86.png
# /kaggle/input/BATIKK/Batik Truntum/40.jpg
# /kaggle/input/BATIKK/Batik Truntum/84.jpg
# /kaggle/input/BATIKK/Batik Truntum/67.jpg
# /kaggle/input/BATIKK/Batik Truntum/30.jpg
# /kaggle/input/BATIKK/Batik Truntum/89.jpg
# /kaggle/input/BATIKK/Batik Truntum/82.jpg
# /kaggle/input/BATIKK/Batik Truntum/34.jpg
# /kaggle/input/BATIKK/Batik Truntum/72.jpg
# /kaggle/input/BATIKK/Batik Truntum/18.jpg
# /kaggle/input/BATIKK/Batik Truntum/45.jpg
# /kaggle/input/BATIKK/Batik Truntum/11.jpg
# /kaggle/input/BATIKK/Batik Truntum/50.jpg
# /kaggle/input/BATIKK/Batik Truntum/20.jpg
# /kaggle/input/BATIKK/Batik Truntum/73.png
# /kaggle/input/BATIKK/Batik Truntum/56.jpg
# /kaggle/input/BATIKK/Batik Truntum/54.jpg
# /kaggle/input/BATIKK/Batik Truntum/22.jpg
# /kaggle/input/BATIKK/Batik Truntum/1.jpg
# /kaggle/input/BATIKK/Batik Truntum/15.jpg
# /kaggle/input/BATIKK/Batik Truntum/58.jpg
# /kaggle/input/BATIKK/Batik Truntum/77.jpg
# /kaggle/input/BATIKK/Batik Truntum/29.jpg
# /kaggle/input/BATIKK/Batik Truntum/88.jpg
# /kaggle/input/BATIKK/Batik Truntum/78.jpg
# /kaggle/input/BATIKK/Batik Truntum/9.png
# /kaggle/input/BATIKK/Batik Truntum/68.jpg
# /kaggle/input/BATIKK/Batik Truntum/17.jpg
# /kaggle/input/BATIKK/Batik Truntum/35.jpg
# /kaggle/input/BATIKK/Batik Truntum/51.jpg
# /kaggle/input/BATIKK/Batik Truntum/70.jpg
# /kaggle/input/BATIKK/Batik Truntum/44.jpg
# /kaggle/input/BATIKK/Batik Truntum/23.jpg
# /kaggle/input/BATIKK/Batik Truntum/55.jpg
# /kaggle/input/BATIKK/Batik Truntum/46.jpg
# /kaggle/input/BATIKK/Batik Truntum/31.jpg
# /kaggle/input/BATIKK/Batik Truntum/94.jpg
# /kaggle/input/BATIKK/Batik Truntum/3.jpg
# /kaggle/input/BATIKK/Batik Truntum/57.jpg
# /kaggle/input/BATIKK/Batik Truntum/37.jpg
# /kaggle/input/BATIKK/Batik Truntum/8.jpg
# /kaggle/input/BATIKK/Batik Truntum/65.jpg
# /kaggle/input/BATIKK/Batik Truntum/98.jpg
# /kaggle/input/BATIKK/Batik Truntum/10.png
# /kaggle/input/BATIKK/Batik Truntum/7.jpg
# /kaggle/input/BATIKK/Batik Truntum/60.jpg
# /kaggle/input/BATIKK/Batik Truntum/14.jpg
# /kaggle/input/BATIKK/Batik Truntum/63.JPG
# /kaggle/input/BATIKK/Batik Truntum/66.jpg
# /kaggle/input/BATIKK/Batik Truntum/4.jpg
# /kaggle/input/BATIKK/Batik Truntum/28.jpg
# /kaggle/input/BATIKK/Batik Truntum/47.jpg
# /kaggle/input/BATIKK/Batik Truntum/19.jpg
# /kaggle/input/BATIKK/Batik Truntum/93.jpg
# /kaggle/input/BATIKK/Batik Truntum/62.jpg
# /kaggle/input/BATIKK/Batik Truntum/5.jpg
# /kaggle/input/BATIKK/Batik Truntum/6.jpg
# /kaggle/input/BATIKK/Batik Truntum/16.jpg
# /kaggle/input/BATIKK/Batik Truntum/52.jpg
# /kaggle/input/BATIKK/Batik Truntum/41.jpg
# /kaggle/input/BATIKK/Batik Truntum/27.jpg
# /kaggle/input/BATIKK/Batik Truntum/43.png
# /kaggle/input/BATIKK/Batik Truntum/80.jpg
# /kaggle/input/BATIKK/Batik Truntum/39.jpg
# /kaggle/input/BATIKK/Batik Truntum/74.jpg
# /kaggle/input/BATIKK/Batik Truntum/32.jpg
# /kaggle/input/BATIKK/Batik Truntum/36.jpg
# /kaggle/input/BATIKK/Batik Truntum/75.png
# /kaggle/input/BATIKK/Batik Mega Mendung/87.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/38.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/99.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/90.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/76.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/73.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/97.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/42.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/49.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/48.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/75.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/64.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/69.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/13.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/91.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/71.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/12.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/59.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/43.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/2.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/92.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/33.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/85.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/100.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/24.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/21.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/95.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/25.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/61.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/96.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/10.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/53.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/81.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/79.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/40.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/5.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/84.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/67.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/89.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/9.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/34.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/23.gif
# /kaggle/input/BATIKK/Batik Mega Mendung/83.png
# /kaggle/input/BATIKK/Batik Mega Mendung/72.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/18.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/45.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/11.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/50.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/30.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/20.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/56.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/54.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/22.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/86.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/1.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/15.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/63.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/58.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/77.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/88.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/78.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/68.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/17.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/46.png
# /kaggle/input/BATIKK/Batik Mega Mendung/7.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/35.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/51.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/70.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/44.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/55.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/31.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/94.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/3.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/57.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/27.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/8.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/65.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/98.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/6.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/60.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/29.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/14.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/66.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/4.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/26.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/47.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/37.png
# /kaggle/input/BATIKK/Batik Mega Mendung/19.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/93.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/62.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/28.jpeg
# /kaggle/input/BATIKK/Batik Mega Mendung/82.png
# /kaggle/input/BATIKK/Batik Mega Mendung/16.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/52.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/41.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/80.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/39.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/74.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/32.jpg
# /kaggle/input/BATIKK/Batik Mega Mendung/36.jpg
# /kaggle/input/BATIKK/Batik Kawung/34.png
# /kaggle/input/BATIKK/Batik Kawung/87.jpg
# /kaggle/input/BATIKK/Batik Kawung/46.jpeg
# /kaggle/input/BATIKK/Batik Kawung/38.jpg
# /kaggle/input/BATIKK/Batik Kawung/99.jpg
# /kaggle/input/BATIKK/Batik Kawung/90.jpg
# /kaggle/input/BATIKK/Batik Kawung/76.jpg
# /kaggle/input/BATIKK/Batik Kawung/97.jpg
# /kaggle/input/BATIKK/Batik Kawung/42.jpg
# /kaggle/input/BATIKK/Batik Kawung/49.jpg
# /kaggle/input/BATIKK/Batik Kawung/48.jpg
# /kaggle/input/BATIKK/Batik Kawung/75.jpg
# /kaggle/input/BATIKK/Batik Kawung/64.jpg
# /kaggle/input/BATIKK/Batik Kawung/3.jpeg
# /kaggle/input/BATIKK/Batik Kawung/69.jpg
# /kaggle/input/BATIKK/Batik Kawung/13.jpg
# /kaggle/input/BATIKK/Batik Kawung/91.jpg
# /kaggle/input/BATIKK/Batik Kawung/44.jpeg
# /kaggle/input/BATIKK/Batik Kawung/71.jpg
# /kaggle/input/BATIKK/Batik Kawung/83.jpg
# /kaggle/input/BATIKK/Batik Kawung/12.jpg
# /kaggle/input/BATIKK/Batik Kawung/10.jpeg
# /kaggle/input/BATIKK/Batik Kawung/59.jpg
# /kaggle/input/BATIKK/Batik Kawung/43.jpg
# /kaggle/input/BATIKK/Batik Kawung/2.jpg
# /kaggle/input/BATIKK/Batik Kawung/92.jpg
# /kaggle/input/BATIKK/Batik Kawung/33.jpg
# /kaggle/input/BATIKK/Batik Kawung/85.jpg
# /kaggle/input/BATIKK/Batik Kawung/100.jpg
# /kaggle/input/BATIKK/Batik Kawung/24.jpg
# /kaggle/input/BATIKK/Batik Kawung/21.jpg
# /kaggle/input/BATIKK/Batik Kawung/95.jpg
# /kaggle/input/BATIKK/Batik Kawung/25.jpg
# /kaggle/input/BATIKK/Batik Kawung/61.jpg
# /kaggle/input/BATIKK/Batik Kawung/96.jpg
# /kaggle/input/BATIKK/Batik Kawung/53.jpg
# /kaggle/input/BATIKK/Batik Kawung/22.png
# /kaggle/input/BATIKK/Batik Kawung/81.jpg
# /kaggle/input/BATIKK/Batik Kawung/79.jpg
# /kaggle/input/BATIKK/Batik Kawung/40.jpg
# /kaggle/input/BATIKK/Batik Kawung/35.png
# /kaggle/input/BATIKK/Batik Kawung/84.jpg
# /kaggle/input/BATIKK/Batik Kawung/67.jpg
# /kaggle/input/BATIKK/Batik Kawung/89.jpg
# /kaggle/input/BATIKK/Batik Kawung/82.jpg
# /kaggle/input/BATIKK/Batik Kawung/72.jpg
# /kaggle/input/BATIKK/Batik Kawung/18.jpg
# /kaggle/input/BATIKK/Batik Kawung/50.jpg
# /kaggle/input/BATIKK/Batik Kawung/20.jpg
# /kaggle/input/BATIKK/Batik Kawung/73.png
# /kaggle/input/BATIKK/Batik Kawung/56.jpg
# /kaggle/input/BATIKK/Batik Kawung/54.jpg
# /kaggle/input/BATIKK/Batik Kawung/86.jpg
# /kaggle/input/BATIKK/Batik Kawung/1.jpg
# /kaggle/input/BATIKK/Batik Kawung/15.jpg
# /kaggle/input/BATIKK/Batik Kawung/63.jpg
# /kaggle/input/BATIKK/Batik Kawung/58.jpg
# /kaggle/input/BATIKK/Batik Kawung/77.jpg
# /kaggle/input/BATIKK/Batik Kawung/88.jpg
# /kaggle/input/BATIKK/Batik Kawung/78.jpg
# /kaggle/input/BATIKK/Batik Kawung/68.jpg
# /kaggle/input/BATIKK/Batik Kawung/17.jpg
# /kaggle/input/BATIKK/Batik Kawung/9.jpeg
# /kaggle/input/BATIKK/Batik Kawung/7.jpeg
# /kaggle/input/BATIKK/Batik Kawung/8.jpeg
# /kaggle/input/BATIKK/Batik Kawung/51.jpg
# /kaggle/input/BATIKK/Batik Kawung/70.jpg
# /kaggle/input/BATIKK/Batik Kawung/23.jpg
# /kaggle/input/BATIKK/Batik Kawung/55.jpg
# /kaggle/input/BATIKK/Batik Kawung/11.jpeg
# /kaggle/input/BATIKK/Batik Kawung/31.jpg
# /kaggle/input/BATIKK/Batik Kawung/94.jpg
# /kaggle/input/BATIKK/Batik Kawung/57.jpg
# /kaggle/input/BATIKK/Batik Kawung/37.jpg
# /kaggle/input/BATIKK/Batik Kawung/45.jpeg
# /kaggle/input/BATIKK/Batik Kawung/30.png
# /kaggle/input/BATIKK/Batik Kawung/65.jpg
# /kaggle/input/BATIKK/Batik Kawung/98.jpg
# /kaggle/input/BATIKK/Batik Kawung/6.jpeg
# /kaggle/input/BATIKK/Batik Kawung/60.jpg
# /kaggle/input/BATIKK/Batik Kawung/14.jpg
# /kaggle/input/BATIKK/Batik Kawung/66.jpg
# /kaggle/input/BATIKK/Batik Kawung/4.jpg
# /kaggle/input/BATIKK/Batik Kawung/26.jpeg
# /kaggle/input/BATIKK/Batik Kawung/28.jpg
# /kaggle/input/BATIKK/Batik Kawung/47.jpg
# /kaggle/input/BATIKK/Batik Kawung/19.jpg
# /kaggle/input/BATIKK/Batik Kawung/93.jpg
# /kaggle/input/BATIKK/Batik Kawung/62.jpg
# /kaggle/input/BATIKK/Batik Kawung/5.jpg
# /kaggle/input/BATIKK/Batik Kawung/16.jpg
# /kaggle/input/BATIKK/Batik Kawung/29.png
# /kaggle/input/BATIKK/Batik Kawung/52.jpg
# /kaggle/input/BATIKK/Batik Kawung/41.jpg
# /kaggle/input/BATIKK/Batik Kawung/27.jpg
# /kaggle/input/BATIKK/Batik Kawung/80.jpg
# /kaggle/input/BATIKK/Batik Kawung/39.jpg
# /kaggle/input/BATIKK/Batik Kawung/74.jpg
# /kaggle/input/BATIKK/Batik Kawung/32.jpg
# /kaggle/input/BATIKK/Batik Kawung/36.jpg
# /kaggle/input/BATIKK/Batik Semarangan/87.jpg
# /kaggle/input/BATIKK/Batik Semarangan/38.jpg
# /kaggle/input/BATIKK/Batik Semarangan/99.jpg
# /kaggle/input/BATIKK/Batik Semarangan/90.jpg
# /kaggle/input/BATIKK/Batik Semarangan/76.jpg
# /kaggle/input/BATIKK/Batik Semarangan/97.jpg
# /kaggle/input/BATIKK/Batik Semarangan/42.jpg
# /kaggle/input/BATIKK/Batik Semarangan/49.jpg
# /kaggle/input/BATIKK/Batik Semarangan/75.jpg
# /kaggle/input/BATIKK/Batik Semarangan/64.jpg
# /kaggle/input/BATIKK/Batik Semarangan/26.jpg
# /kaggle/input/BATIKK/Batik Semarangan/36.jpeg
# /kaggle/input/BATIKK/Batik Semarangan/69.jpg
# /kaggle/input/BATIKK/Batik Semarangan/13.jpg
# /kaggle/input/BATIKK/Batik Semarangan/91.jpg
# /kaggle/input/BATIKK/Batik Semarangan/71.jpg
# /kaggle/input/BATIKK/Batik Semarangan/83.jpg
# /kaggle/input/BATIKK/Batik Semarangan/12.jpg
# /kaggle/input/BATIKK/Batik Semarangan/59.jpg
# /kaggle/input/BATIKK/Batik Semarangan/43.jpg
# /kaggle/input/BATIKK/Batik Semarangan/2.jpg
# /kaggle/input/BATIKK/Batik Semarangan/56.JPG
# /kaggle/input/BATIKK/Batik Semarangan/92.jpg
# /kaggle/input/BATIKK/Batik Semarangan/33.jpg
# /kaggle/input/BATIKK/Batik Semarangan/85.jpg
# /kaggle/input/BATIKK/Batik Semarangan/100.jpg
# /kaggle/input/BATIKK/Batik Semarangan/24.jpg
# /kaggle/input/BATIKK/Batik Semarangan/21.jpg
# /kaggle/input/BATIKK/Batik Semarangan/95.jpg
# /kaggle/input/BATIKK/Batik Semarangan/25.jpg
# /kaggle/input/BATIKK/Batik Semarangan/61.jpg
# /kaggle/input/BATIKK/Batik Semarangan/96.jpg
# /kaggle/input/BATIKK/Batik Semarangan/10.jpg
# /kaggle/input/BATIKK/Batik Semarangan/81.jpg
# /kaggle/input/BATIKK/Batik Semarangan/79.jpg
# /kaggle/input/BATIKK/Batik Semarangan/20.png
# /kaggle/input/BATIKK/Batik Semarangan/32.jpeg
# /kaggle/input/BATIKK/Batik Semarangan/35.jpeg
# /kaggle/input/BATIKK/Batik Semarangan/53.jpeg
# /kaggle/input/BATIKK/Batik Semarangan/40.jpg
# /kaggle/input/BATIKK/Batik Semarangan/84.jpg
# /kaggle/input/BATIKK/Batik Semarangan/67.jpg
# /kaggle/input/BATIKK/Batik Semarangan/30.jpg
# /kaggle/input/BATIKK/Batik Semarangan/89.jpg
# /kaggle/input/BATIKK/Batik Semarangan/48.JPG
# /kaggle/input/BATIKK/Batik Semarangan/9.jpg
# /kaggle/input/BATIKK/Batik Semarangan/34.jpeg
# /kaggle/input/BATIKK/Batik Semarangan/72.jpg
# /kaggle/input/BATIKK/Batik Semarangan/18.jpg
# /kaggle/input/BATIKK/Batik Semarangan/45.jpg
# /kaggle/input/BATIKK/Batik Semarangan/11.jpg
# /kaggle/input/BATIKK/Batik Semarangan/50.jpg
# /kaggle/input/BATIKK/Batik Semarangan/73.png
# /kaggle/input/BATIKK/Batik Semarangan/54.jpg
# /kaggle/input/BATIKK/Batik Semarangan/22.jpg
# /kaggle/input/BATIKK/Batik Semarangan/86.jpg
# /kaggle/input/BATIKK/Batik Semarangan/1.jpg
# /kaggle/input/BATIKK/Batik Semarangan/15.jpg
# /kaggle/input/BATIKK/Batik Semarangan/58.jpg
# /kaggle/input/BATIKK/Batik Semarangan/77.jpg
# /kaggle/input/BATIKK/Batik Semarangan/29.jpg
# /kaggle/input/BATIKK/Batik Semarangan/88.jpg
# /kaggle/input/BATIKK/Batik Semarangan/78.jpg
# /kaggle/input/BATIKK/Batik Semarangan/68.jpg
# /kaggle/input/BATIKK/Batik Semarangan/17.jpg
# /kaggle/input/BATIKK/Batik Semarangan/51.jpg
# /kaggle/input/BATIKK/Batik Semarangan/70.jpg
# /kaggle/input/BATIKK/Batik Semarangan/44.jpg
# /kaggle/input/BATIKK/Batik Semarangan/23.jpg
# /kaggle/input/BATIKK/Batik Semarangan/55.jpg
# /kaggle/input/BATIKK/Batik Semarangan/46.jpg
# /kaggle/input/BATIKK/Batik Semarangan/31.jpg
# /kaggle/input/BATIKK/Batik Semarangan/94.jpg
# /kaggle/input/BATIKK/Batik Semarangan/3.jpg
# /kaggle/input/BATIKK/Batik Semarangan/57.jpg
# /kaggle/input/BATIKK/Batik Semarangan/37.jpg
# /kaggle/input/BATIKK/Batik Semarangan/8.jpg
# /kaggle/input/BATIKK/Batik Semarangan/65.jpg
# /kaggle/input/BATIKK/Batik Semarangan/98.jpg
# /kaggle/input/BATIKK/Batik Semarangan/7.jpg
# /kaggle/input/BATIKK/Batik Semarangan/60.jpg
# /kaggle/input/BATIKK/Batik Semarangan/14.jpg
# /kaggle/input/BATIKK/Batik Semarangan/63.JPG
# /kaggle/input/BATIKK/Batik Semarangan/66.jpg
# /kaggle/input/BATIKK/Batik Semarangan/4.jpg
# /kaggle/input/BATIKK/Batik Semarangan/28.jpg
# /kaggle/input/BATIKK/Batik Semarangan/47.jpg
# /kaggle/input/BATIKK/Batik Semarangan/19.jpg
# /kaggle/input/BATIKK/Batik Semarangan/93.jpg
# /kaggle/input/BATIKK/Batik Semarangan/62.jpg
# /kaggle/input/BATIKK/Batik Semarangan/5.jpg
# /kaggle/input/BATIKK/Batik Semarangan/6.jpg
# /kaggle/input/BATIKK/Batik Semarangan/82.png
# /kaggle/input/BATIKK/Batik Semarangan/16.jpg
# /kaggle/input/BATIKK/Batik Semarangan/52.jpg
# /kaggle/input/BATIKK/Batik Semarangan/41.jpg
# /kaggle/input/BATIKK/Batik Semarangan/27.jpg
# /kaggle/input/BATIKK/Batik Semarangan/80.jpg
# /kaggle/input/BATIKK/Batik Semarangan/39.jpg
# /kaggle/input/BATIKK/Batik Semarangan/74.jpg

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Oh, no! There are no automatic insights available for the file types used in this dataset. As your Kaggle kerneler bot, I'll keep working to fine-tune my hyper-parameters. In the meantime, please feel free to try a different dataset.

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Fork Notebook" button at the top of this kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
